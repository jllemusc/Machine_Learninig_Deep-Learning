# %% [markdown]
#  **DataSet Boston**

# %%
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import statistics

# %%
boston = load_boston()
X = boston.data
Y = boston.target
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
x  = range(0, boston.data.shape[0],1) #same as x = range(0,len(y),1)
x
# Out:
# range(0, 506)

# %%
CRIME = 0 ; ZN =1 ; INDUSTRIAL =2 ; ROOMS =5; DISTANCE = 7

# %% [markdown]
# Plot Several features

# %%
plt.figure(figsize = (30,8))
plt.plot(x, X[:,INDUSTRIAL], 'y-', label ='Industrial')
plt.plot(x, X[:,DISTANCE], 'b-', label = 'Distance')
plt.plot(x, X[:,ROOMS],'c-', label = 'Rooms')
plt.rcParams.update({'font.size':18});
plt.legend(prop = {'size':22});
plt.grid();

# %%
boston.DESCR #Text information about this dataset
# Out:
# ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,0
# ...

# %%
print(X.shape)
print(Y.shape)
# Out:
# (506, 13)
# (506,)

# %% [markdown]
# This dataset contains 506 samples (rows) and 13 features (columns), we could use this dataset for regression given the target are numbers.

# %%
print(X[0:3,:]) #Print rows of data, starting from 1 to row 3
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 0.0000e+00 5.3800e-01 6.5750e+00
#   6.5200e+01 4.0900e+00 1.0000e+00 2.9600e+02 1.5300e+01 3.9690e+02
#   4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 6.4210e+00
#   7.8900e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9690e+02
#   9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 0.0000e+00 4.6900e-01 7.1850e+00
#   6.1100e+01 4.9671e+00 2.0000e+00 2.4200e+02 1.7800e+01 3.9283e+02
#   4.0300e+00]]

# %%
print (y[0:5]) #rows of target data
# Out:
# [24.  21.6 34.7 33.4 36.2]

# %%
print(X[0,ROOMS]) # print the feature rooms from the first row
# Out:
# 6.575

# %%
print(X[1:3,CRIME]) # print the feature CRIME for rows 2 and 3
# Out:
# [0.02731 0.02729]

# %%
print(boston.data.shape[0])
print(boston.data.shape[1])
# Out:
# 506
# 13

# %% [markdown]
# Obtains the mean and the variance of each feature

# %%
mean=[] ; variance = []
for i in range(boston.data.shape[1]):
               mean.append(statistics.mean(X[:,i]))
               variance.append(statistics.variance(X[:,i]))

#Prints each feature mean and variace
for i in range(boston.data.shape[1]):
  print(format(i) + ": mean:{:.2f}".format(mean[i]) + ", variance:{:.2f}'".format(variance[i]))
# Out:
# 0: mean:3.61, variance:73.99'
# 1: mean:11.36, variance:543.94'
# 2: mean:11.14, variance:47.06'
# 3: mean:0.07, variance:0.06'
# 4: mean:0.55, variance:0.01'
# 5: mean:6.28, variance:0.49'
# 6: mean:68.57, variance:792.36'
# 7: mean:3.80, variance:4.43'
# 8: mean:9.55, variance:75.82'
# 9: mean:408.24, variance:28404.76'
# 10: mean:18.46, variance:4.69'
# 11: mean:356.67, variance:8334.75'
# 12: mean:12.65, variance:50.99'

# %%
fig = plt.figure( figsize =(16,8))
ax = fig.add_subplot(projection='3d', elev=35, azim = 15)

ax.scatter(X[:,DISTANCE],  X[:,ROOMS], y ,c='r', marker='^')

ax.set_xlabel('Distance', fontsize = 15)
ax.set_ylabel('Rooms', fontsize = 15)
ax.set_zlabel('Boston', fontsize = 15)
ax.tick_params(axis='both', which='major', labelsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# With this plot we can find some kind of relationship between the price the distance and the number of rooms,  less distance and more rooms increase the price of the property
