# %% [markdown]
# **Make Blobs**

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %% [markdown]
# Generate the data

# %%
X,y = make_blobs(n_samples = 250, n_features= 2, centers =4 , random_state=9)

# %% [markdown]
# Plot the data

# %%
plt.figure(figsize=(5,5))
for target, color, marker in zip(range(4),['y','r','b','g'],['o','^','+','*']):
  plt.scatter(X[y==target,0],X[y==target,1],c=color, marker=marker, label='class '+ format(target))

plt.xlabel('Feature 1', fontsize= 15)
plt.ylabel('Feature 2', fontsize = 15)
plt.title('Four Classes Scatter Plot')

plt.legend(prop={'size':14})
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
