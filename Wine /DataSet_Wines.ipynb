# %% [markdown]
# **DataSet Wines**

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.preprocessing import MinMaxScaler

# %%
wine = load_wine()
x = range (0, wine.data.shape[0],1) # sames as x = range(0, len(y),1)
print(f'Shape of the data: {wine.data.shape}')
# Out:
# Shape of the data: (178, 13)

# %%
scaler = MinMaxScaler()
scaler.fit(wine.data)
wine.scaled = scaler.transform(wine.data) #We normalized the data to be able to make comparisons

# %%
def plot(init_feature, end_feature, mark):
  plt.figure(figsize =(30,5))
  for i in range (init_feature, end_feature,1):
    plt.plot(x, wine.scaled[:,i],mark, label = wine.feature_names[i])
  plt.rcParams.update({'font.size':12});
  plt.legend(prop={'size':11});
  plt.grid()
  plt.show()

# %% [markdown]
# Plot all the feautures

# %%
plot(0,4,'-')
plot(4,8,'o')
plot(8,12,'^')
